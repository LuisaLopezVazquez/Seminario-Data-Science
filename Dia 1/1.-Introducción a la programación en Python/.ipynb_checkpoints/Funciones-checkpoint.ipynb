# %%
def licuar(fruta):
    ##Contenido
    if fruta=="fresa":
        print("El sabor de tu licuado es:"+ fruta)
    elif fruta=="platano":
        print("El sabor de tu licuado es:"+ fruta)
    elif fruta=="manzana":
        print("El sabor de tu licuado es:" + fruta)

sabor_licuado = licuar("platano") # llamamos a la funcion
# Out:
# El sabor de tu licuado es:platano
