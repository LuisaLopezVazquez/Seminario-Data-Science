# %% [markdown]
# Hola mi primer programa

# %%
nombres = ["Yahir","Perla","Jose","Sonia","Pedro"]
nombres
# Out:
# ['Yahir', 'Perla', 'Jose', 'Sonia', 'Pedro']

# %%
nombres.append("Maria") #Permite agregar un elemento
nombres
# Out:
# ['Yahir', 'Perla', 'Jose', 'Sonia', 'Pedro', 'Maria', 'Maria']

# %%
nombres.extend(["Raul","Karla"])
nombres
# Out:
# ['Yahir', 'Perla', 'Jose', 'Sonia', 'Pedro', 'Maria', 'Maria', 'Raul', 'Karla']

# %%
nombres.remove("Maria")

# %%
nombres
# Out:
# ['Yahir', 'Perla', 'Jose', 'Sonia', 'Pedro', 'Raul', 'Karla']

# %%
total= len(nombres) #Obtenemos el tamaño de la lista
total
# Out:
# 7

# %%
nombres.extend([56,58,59])
nombres
# Out:
# ['Yahir', 'Perla', 'Jose', 'Sonia', 'Pedro', 'Raul', 'Karla', 56, 58, 59]

# %%
type(nombres)
# Out:
# list

# %%
lista=[100,89,2,56,2,20,2,1]
lista
# Out:
# [100, 89, 2, 56, 2, 20, 2, 1]

# %%
lista.sort() #Para ordenar

# %%
lista
# Out:
# [1, 2, 2, 2, 20, 56, 89, 100]

# %%
max(lista)
# Out:
# 89

# %%
min(lista)
# Out:
# 2

# %%
lista.reverse()
lista
# Out:
# [100, 89, 56, 20, 2, 2, 2, 1]

# %% [markdown]
# ## Diccionarios

# %%
familia={"abuela": {"nombre":"Carmen", "edad":71},
         "abuelo": {"nombre":"Jose", "edad":75}
        }
print(familia["abuela"]["nombre"])
# Out:
# Carmen

# %%
familia["abuela"]["ocupacion"] = "Ventas"

# %%
familia
# Out:
# {'abuela': {'nombre': 'Carmen', 'edad': 71, 'ocupacion': 'Ventas'},
#  'abuelo': {'nombre': 'Jose', 'edad': 75}}

# %%
tupla_frutas=("manzana","naranja","fresa","mango")
tupla_frutas
# Out:
# ('manzana', 'naranja', 'fresa', 'mango')

# %%
type(tupla_frutas)
# Out:
# tuple
