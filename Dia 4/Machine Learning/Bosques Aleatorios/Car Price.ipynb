# %% [markdown]
# <h2><font color="#004D7F" size=6>Módulo 3. Machine Learning</font></h2>
#
#
#
# <h1><font color="#004D7F" size=5> Bosques Aleatorios</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#004D7F" size=3>Seminario de Ciencia de Datos</font><br>

# %% [markdown]
# Planteamiento del problema
# Una empresa automovilística Mexicana, DINA, aspira a entrar en el mercado estadounidense estableciendo allí su unidad de fabricación y produciendo automóviles localmente para competir con sus contrapartes estadounidenses y europeas.
#
# Han contratado a una empresa de consultoría de automóviles para comprender los factores de los que depende el precio de los automóviles. Específicamente, quieren comprender los factores que afectan el precio de los automóviles en el mercado estadounidense, ya que pueden ser muy diferentes del mercado Mexicano. La empresa quiere saber:
#
# ¿Qué variables son significativas para predecir el precio de un automóvil?
#
# Qué tan bien esas variables describen el precio de un automóvil
# Con base en varias encuestas de mercado, la consultora ha recopilado un gran conjunto de datos de diferentes tipos de automóviles en todo el mercado estadounidense.

# %% [markdown]
# Objetivo comercial
# Estamos obligados a modelar el precio de los automóviles con las variables independientes disponibles. La gerencia lo utilizará para comprender cómo varían exactamente los precios con las variables independientes. En consecuencia, pueden manipular el diseño de los automóviles, la estrategia comercial, etc. para cumplir con ciertos niveles de precios. Además, el modelo será una buena manera para que la gerencia entienda la dinámica de precios de un nuevo mercado.

# %%
#Importación de las bibliotecas básicas para el análisis
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")  #Usando el estilo ggplot
# %matplotlib inline

# %%
#Importing el dataset

# mostrar los primeros registros del dataset

# %%
#Mirando la forma del conjunto de datos

# %%
#Comprobando los tipos de datos de todas las columnas

# %%
#comprobando el valor nulo

# %%
#comprobando el valor duplicado

# %%
# buscando describir conjunto de datos

# %%
#Describir el valor del precio

# %%
# eliminar la columna car ID \ no es necearia

# %%
#mostrar cuál  tipo de combustible es el mas utilizado

# %%
# El precio medio depende del tipo de combustible.

# %%
# crear grafica

# %%
# Cuál es la mayor cantidad de repeticiones de aspiración en el conjunto de datos [auto estándar o auto turbo]

# %%
# El precio promedio depende de Estándar o Turbo

# %%
# grafica de barras

# %%
# Cuál es la mayor cantidad de repeticiones de números de puerta en el conjunto de datos [2 o 4]

# %%
# el precio medio depende del número de puerta

# %%
# crear grafica

# %%
# ¿Cuál es la mayor cantidad de repeticiones de carrocerías en el conjunto de datos?

# %%
# el precio medio depende de la carrocería

# %%
# crear grafica

# %%
# ¿Cuál es la mayor cantidad de repeticiones de ruedas motrices de automóviles en el conjunto de datos?

# %%
# el precio promedio depende de la rueda motriz

# %%
# crear grafica

# %%
# ¿Cuál es la mayoría de las repeticiones del tipo de motor en el conjunto de datos?

# %%
# el precio medio [tipo de motor]

# %%
#crear grafica

# %%
# ¿Cuál es la mayor cantidad de repeticiones del número de cilindro en el conjunto de datos?

# %%
# el precio medio depende del número de cilindros

# %%
# crear grafica

# %%
# para mostrar la relación entre el tamaño del motor y el precio

# %%
# estos son algunos gráficos para mostrar la distancia entre ejes, la longitud del automóvil, el ancho del automóvil, la altura del automóvil si tiene algún efecto en el precio

fig = plt.figure(figsize=(26, 12))

# %% [markdown]
# ## Construcción de un modelo de aprendizaje automático

# %%
#Importing the basic librarires for building model

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_absolute_error ,mean_squared_error, median_absolute_error,confusion_matrix,accuracy_score,r2_score

from sklearn.linear_model import LinearRegression ,ARDRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
# mostrar datos del dataset

# %%
#mostrar el tipo de datos

# %%
# crear copia en el conjunto de datos original

# %%
# Separación de las columnas de tipos de datos [objeto y numérico]

# %%
 # Deshabilitar warnings
import warnings
warnings.filterwarnings("ignore")

# %%
 # merge 2 data set

# %%
# Veamos la correlación entre todas las características en el precio.

# %%
# Quiero elegir estas columnas porque tiene corr en el precio

# %% [markdown]
# ## Antes de aplicar el  Standardscaler

# %%
#Definió el valor X y el valor y, y dividió el tren de datos

# split the data train and test

# %%
#Objeto definido de la biblioteca Regresión

# %%
# make for loop for Regression

# %%
# hacer un gráfico sobre la precisión

# %% [markdown]
# ## Después de aplicar el Standardscaler

# %%
#Se define el valor X y el valor Y, y se divide el tren de datos

# %%
# split the data train and test

# %%
# make for loop for Regression

# %%
# Mostrar las predicciones por algoritmo

# %%
# Graficar las predicciones realizadas por cada algoritmo

# %%
# Conclusiones
